# %% [markdown]
# <a href="https://colab.research.google.com/github/kaushal-create/BTP/blob/master/BTP_pd.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tensorboardX

# %% [markdown]
# Cloning code from Github profile

# %%
# !git clone https://github.com/kaushal-create/BTP.git
# Out:
# Cloning into 'BTP'...
# remote: Enumerating objects: 169, done.
# remote: Counting objects: 100% (75/75), done.
# remote: Compressing objects: 100% (75/75), done.
# remote: Total 169 (delta 41), reused 0 (delta 0), pack-reused 94
# Receiving objects: 100% (169/169), 8.79 MiB | 5.05 MiB/s, done.
# Resolving deltas: 100% (79/79), done.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd BTP
# Out:
# /content/BTP

# %% [markdown]
# Trainig model

# %%
# !python3 main.py --save_path save/moel/
# Out:
# ...
#                                       Opts
# --------------------------------------------------------------------------------
#                                 dataset: empathetic
#                              hidden_dim: 300
#                                 emb_dim: 300
#                              batch_size: 16
#                                      lr: 0.0001
#                           max_grad_norm: 2.0
#                               beam_size: 5
#                               save_path: save/moel/
#                       save_path_dataset: save/
#                                    cuda: 1
#                           basic_learner: 1
#                                    topk: 5
#                                 softmax: 1
#                                schedule: 10000
#                            pretrain_emb: 1
#                                   model: experts
#                                    noam: 1
#                         act_loss_weight: 0.001
# ...

# %% [markdown]
# Testing of model

# %%
# %ls save/moel
# Out:
# config.txt                                   model_599_1665.1422_0.0000_0.0000_0.0000_0.0000
# events.out.tfevents.1706377375.98ca1c849db1  model_799_1022.8607_0.0000_0.0000_0.0000_0.0000
# lr/                                          model_999_676.8519_0.0000_0.0000_0.0000_0.0000

# %%
# !python3 interact.py --save_path save/moel/model_999_676.8519_0.0000_0.0000_0.0000_0.0000

import matplotlib.pyplot as plt
# Load the saved image
image_path = 'emotion_plot.png'  # Adjust the filename and path accordingly
image = plt.imread(image_path)

# Display the loaded image
plt.imshow(image)
plt.axis('off')  # Optional: Turn off axis labels and ticks
plt.show()
# Out:
# ...
#                                       Opts
# --------------------------------------------------------------------------------
#                                 dataset: empathetic
#                              hidden_dim: 300
#                                 emb_dim: 300
#                              batch_size: 16
#                                      lr: 0.0001
#                           max_grad_norm: 2.0
#                               beam_size: 5
#                      save_path: save/moel/model_999_676.8519_0.0000_0.0000_0.0000_0.0000
#                       save_path_dataset: save/
#                                    cuda: 1
#                           basic_learner: 1
#                                    topk: 5
#                                 softmax: 1
#                                schedule: 10000
#                            pretrain_emb: 1
#                                   model: experts
#                                    noam: 1
# ...
